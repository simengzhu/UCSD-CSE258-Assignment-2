# %%
import csv

# %%
# Read csv to list
with open('bank-full.csv', 'rb') as csvfile:
    reader = csv.reader(csvfile, delimiter=';')
    content = []
    for row in reader:
        content.append(row)
attributes = content[0]
content = content[1:]
print 'Attributes:', attributes
print 'Number of data', len(content)
# Out:
# Attributes: ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'y']
# Number of data 45211

# %%
def predict_term_deposit_(data={}):
    """ Predictor for Term deposit? from model/5092db7f1552680e80000042

        The data is related with direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe a term deposit
    """
    if (data.get('duration') is None):
        return u'no'
    if (data['duration'] <= 392):
        if (data.get('month') is None):
            return u'no'
        if (data['month'] == 'oct'):
            if (data['duration'] <= 127):
                return u'no'
            if (data['duration'] > 127):
                if (data.get('poutcome') is None):
                    return u'yes'
                if (data['poutcome'] == 'success'):
                    return u'yes'
                if (data['poutcome'] != 'success'):
                    if (data.get('day') is None):
                        return u'no'
                    if (data['day'] <= 20):
                        return u'no'
                    if (data['day'] > 20):
                        return u'yes'
        if (data['month'] == 'jul'):
            if (data.get('poutcome') is None):
                return u'no'
            if (data['poutcome'] == 'unknown'):
                if (data['duration'] <= 214):
                    if (data.get('age') is None):
                        return u'no'
                    if (data['age'] <= 24):
                        return u'no'
                    if (data['age'] > 24):
                        if (data.get('day') is None):
                            return u'no'
                        if (data['day'] <= 5):
                            return u'no'
                        if (data['day'] > 5):
                            if (data.get('contact') is None):
                                return u'no'
                            if (data['contact'] == 'unknown'):
                                return u'no'
                            if (data['contact'] != 'unknown'):
                                return u'no'
                if (data['duration'] > 214):
                    if (data.get('day') is None):
                        return u'no'
                    if (data['day'] <= 6):
                        if (data.get('contact') is None):
                            return u'no'
                        if (data['contact'] == 'unknown'):
                            return u'no'
                        if (data['contact'] != 'unknown'):
                            return u'yes'
                    if (data['day'] > 6):
                        if (data.get('job') is None):
                            return u'no'
                        if (data['job'] == 'management'):
                            return u'no'
                        if (data['job'] == 'technician'):
                            return u'no'
                        if (data['job'] == 'unemployed'):
                            return u'no'
                        if (data['job'] == 'retired'):
                            if (data.get('age') is None):
                                return u'no'
                            if (data['age'] <= 62):
                                return u'no'
                            if (data['age'] > 62):
                                return u'yes'
                        if (data['job'] == 'unknown'):
                            return u'no'
                        if (data['job'] == 'self-employed'):
                            return u'no'
                        if (data['job'] == 'housemaid'):
                            return u'no'
                        if (data['job'] == 'blue-collar'):
                            return u'no'
                        if (data['job'] == 'entrepreneur'):
                            return u'no'
                        if (data['job'] == 'student'):
                            if (data.get('education') is None):
                                return u'no'
                            if (data['education'] == 'unknown'):
                                return u'yes'
                            if (data['education'] != 'unknown'):
                                return u'no'
                        if (data['job'] == 'services'):
                            if (data.get('balance') is None):
                                return u'no'
                            if (data['balance'] <= 8568):
                                return u'no'
                            if (data['balance'] > 8568):
                                return u'yes'
                        if (data['job'] == 'admin.'):
                            return u'no'
            if (data['poutcome'] != 'unknown'):
                if (data['duration'] <= 160):
                    return u'no'
                if (data['duration'] > 160):
                    if (data['duration'] <= 320):
                        if (data['poutcome'] == 'success'):
                            if (data.get('campaign') is None):
                                return u'yes'
                            if (data['campaign'] <= 3):
                                return u'yes'
                            if (data['campaign'] > 3):
                                return u'no'
                        if (data['poutcome'] != 'success'):
                            return u'no'
                    if (data['duration'] > 320):
                        return u'yes'
        if (data['month'] == 'dec'):
            if (data['duration'] <= 147):
                return u'no'
            if (data['duration'] > 147):
                if (data.get('poutcome') is None):
                    return u'yes'
                if (data['poutcome'] == 'success'):
                    return u'yes'
                if (data['poutcome'] != 'success'):
                    if (data.get('pdays') is None):
                        return u'no'
                    if (data['pdays'] <= 225):
                        if (data['duration'] <= 263):
                            return u'no'
                        if (data['duration'] > 263):
                            if (data['duration'] <= 370):
                                return u'yes'
                            if (data['duration'] > 370):
                                return u'no'
                    if (data['pdays'] > 225):
                        return u'yes'
        if (data['month'] == 'jun'):
            if (data.get('contact') is None):
                return u'no'
            if (data['contact'] == 'unknown'):
                if (data['duration'] <= 364):
                    if (data.get('age') is None):
                        return u'no'
                    if (data['age'] <= 24):
                        return u'no'
                    if (data['age'] > 24):
                        if (data.get('day') is None):
                            return u'no'
                        if (data['day'] <= 8):
                            if (data['duration'] <= 201):
                                return u'no'
                            if (data['duration'] > 201):
                                return u'no'
                        if (data['day'] > 8):
                            return u'no'
                if (data['duration'] > 364):
                    return u'no'
            if (data['contact'] != 'unknown'):
                if (data['duration'] <= 157):
                    return u'no'
                if (data['duration'] > 157):
                    if (data.get('poutcome') is None):
                        return u'yes'
                    if (data['poutcome'] == 'success'):
                        return u'yes'
                    if (data['poutcome'] != 'success'):
                        if (data['duration'] <= 230):
                            return u'no'
                        if (data['duration'] > 230):
                            if (data['duration'] <= 386):
                                return u'yes'
                            if (data['duration'] > 386):
                                return u'no'
        if (data['month'] == 'apr'):
            if (data.get('housing') is None):
                return u'no'
            if (data['housing'] == 'yes'):
                if (data.get('day') is None):
                    return u'no'
                if (data['day'] <= 21):
                    if (data.get('poutcome') is None):
                        return u'no'
                    if (data['poutcome'] == 'success'):
                        if (data.get('contact') is None):
                            return u'no'
                        if (data['contact'] == 'cellular'):
                            if (data['day'] <= 15):
                                return u'yes'
                            if (data['day'] > 15):
                                return u'no'
                        if (data['contact'] == 'telephone'):
                            return u'yes'
                    if (data['poutcome'] != 'success'):
                        if (data['day'] <= 15):
                            return u'no'
                        if (data['day'] > 15):
                            if (data['duration'] <= 367):
                                return u'no'
                            if (data['duration'] > 367):
                                return u'no'
                if (data['day'] > 21):
                    if (data['duration'] <= 224):
                        return u'no'
                    if (data['duration'] > 224):
                        if (data['day'] <= 25):
                            return u'yes'
                        if (data['day'] > 25):
                            if (data['duration'] <= 358):
                                return u'no'
                            if (data['duration'] > 358):
                                return u'yes'
            if (data['housing'] == 'no'):
                if (data['duration'] <= 140):
                    return u'no'
                if (data['duration'] > 140):
                    if (data.get('poutcome') is None):
                        return u'no'
                    if (data['poutcome'] == 'failure'):
                        return u'no'
                    if (data['poutcome'] != 'failure'):
                        if (data['poutcome'] == 'success'):
                            if (data['duration'] <= 156):
                                return u'no'
                            if (data['duration'] > 156):
                                return u'yes'
                        if (data['poutcome'] != 'success'):
                            if (data['duration'] <= 297):
                                return u'no'
                            if (data['duration'] > 297):
                                return u'yes'
        if (data['month'] == 'feb'):
            if (data.get('day') is None):
                return u'no'
            if (data['day'] <= 9):
                if (data.get('poutcome') is None):
                    return u'no'
                if (data['poutcome'] == 'success'):
                    if (data['duration'] <= 148):
                        if (data.get('job') is None):
                            return u'no'
                        if (data['job'] == 'student'):
                            return u'yes'
                        if (data['job'] != 'student'):
                            return u'no'
                    if (data['duration'] > 148):
                        if (data.get('pdays') is None):
                            return u'yes'
                        if (data['pdays'] <= 98):
                            return u'yes'
                        if (data['pdays'] > 98):
                            if (data['duration'] <= 346):
                                return u'no'
                            if (data['duration'] > 346):
                                return u'yes'
                if (data['poutcome'] != 'success'):
                    if (data['duration'] <= 121):
                        if (data['duration'] <= 60):
                            return u'no'
                        if (data['duration'] > 60):
                            return u'no'
                    if (data['duration'] > 121):
                        if (data.get('education') is None):
                            return u'no'
                        if (data['education'] == 'tertiary'):
                            return u'no'
                        if (data['education'] != 'tertiary'):
                            if (data.get('pdays') is None):
                                return u'no'
                            if (data['pdays'] <= 365):
                                return u'no'
                            if (data['pdays'] > 365):
                                return u'yes'
            if (data['day'] > 9):
                if (data['duration'] <= 129):
                    return u'no'
                if (data['duration'] > 129):
                    if (data.get('poutcome') is None):
                        return u'yes'
                    if (data['poutcome'] == 'failure'):
                        if (data.get('age') is None):
                            return u'no'
                        if (data['age'] <= 56):
                            if (data['duration'] <= 156):
                                return u'no'
                            if (data['duration'] > 156):
                                return u'yes'
                        if (data['age'] > 56):
                            return u'no'
                    if (data['poutcome'] != 'failure'):
                        return u'yes'
        if (data['month'] == 'may'):
            if (data.get('poutcome') is None):
                return u'no'
            if (data['poutcome'] == 'success'):
                if (data['duration'] <= 116):
                    return u'no'
                if (data['duration'] > 116):
                    if (data.get('pdays') is None):
                        return u'yes'
                    if (data['pdays'] <= 237):
                        if (data['pdays'] <= 178):
                            if (data['pdays'] <= 98):
                                return u'yes'
                            if (data['pdays'] > 98):
                                return u'no'
                        if (data['pdays'] > 178):
                            if (data.get('job') is None):
                                return u'yes'
                            if (data['job'] == 'self-employed'):
                                return u'no'
                            if (data['job'] != 'self-employed'):
                                return u'yes'
                    if (data['pdays'] > 237):
                        if (data.get('job') is None):
                            return u'no'
                        if (data['job'] == 'services'):
                            if (data.get('balance') is None):
                                return u'yes'
                            if (data['balance'] <= -23):
                                return u'no'
                            if (data['balance'] > -23):
                                return u'yes'
                        if (data['job'] != 'services'):
                            return u'no'
            if (data['poutcome'] != 'success'):
                if (data.get('contact') is None):
                    return u'no'
                if (data['contact'] == 'unknown'):
                    if (data['poutcome'] == 'other'):
                        if (data.get('loan') is None):
                            return u'yes'
                        if (data['loan'] == 'yes'):
                            return u'no'
                        if (data['loan'] == 'no'):
                            return u'yes'
                    if (data['poutcome'] != 'other'):
                        if (data.get('age') is None):
                            return u'no'
                        if (data['age'] <= 34):
                            if (data.get('education') is None):
                                return u'no'
                            if (data['education'] == 'unknown'):
                                return u'no'
                            if (data['education'] != 'unknown'):
                                return u'no'
                        if (data['age'] > 34):
                            return u'no'
                if (data['contact'] != 'unknown'):
                    if (data.get('day') is None):
                        return u'no'
                    if (data['day'] <= 19):
                        if (data['duration'] <= 180):
                            if (data.get('balance') is None):
                                return u'no'
                            if (data['balance'] <= 11826):
                                return u'no'
                            if (data['balance'] > 11826):
                                return u'no'
                        if (data['duration'] > 180):
                            if (data.get('housing') is None):
                                return u'no'
                            if (data['housing'] == 'yes'):
                                return u'no'
                            if (data['housing'] == 'no'):
                                return u'no'
                    if (data['day'] > 19):
                        return u'no'
        if (data['month'] == 'aug'):
            if (data.get('poutcome') is None):
                return u'no'
            if (data['poutcome'] == 'unknown'):
                if (data['duration'] <= 178):
                    if (data.get('age') is None):
                        return u'no'
                    if (data['age'] <= 26):
                        if (data['duration'] <= 164):
                            if (data.get('job') is None):
                                return u'no'
                            if (data['job'] == 'blue-collar'):
                                return u'yes'
                            if (data['job'] != 'blue-collar'):
                                return u'no'
                        if (data['duration'] > 164):
                            return u'yes'
                    if (data['age'] > 26):
                        if (data['age'] <= 60):
                            if (data.get('campaign') is None):
                                return u'no'
                            if (data['campaign'] <= 5):
                                return u'no'
                            if (data['campaign'] > 5):
                                return u'no'
                        if (data['age'] > 60):
                            return u'no'
                if (data['duration'] > 178):
                    if (data.get('campaign') is None):
                        return u'no'
                    if (data['campaign'] <= 1):
                        if (data.get('age') is None):
                            return u'no'
                        if (data['age'] <= 26):
                            if (data.get('balance') is None):
                                return u'yes'
                            if (data['balance'] <= 222):
                                return u'no'
                            if (data['balance'] > 222):
                                return u'yes'
                        if (data['age'] > 26):
                            if (data.get('balance') is None):
                                return u'no'
                            if (data['balance'] <= 9876):
                                return u'no'
                            if (data['balance'] > 9876):
                                return u'yes'
                    if (data['campaign'] > 1):
                        if (data.get('age') is None):
                            return u'no'
                        if (data['age'] <= 59):
                            if (data['age'] <= 27):
                                return u'no'
                            if (data['age'] > 27):
                                return u'no'
                        if (data['age'] > 59):
                            return u'no'
            if (data['poutcome'] != 'unknown'):
                if (data['duration'] <= 127):
                    return u'no'
                if (data['duration'] > 127):
                    if (data['poutcome'] == 'success'):
                        if (data['duration'] <= 170):
                            if (data.get('job') is None):
                                return u'no'
                            if (data['job'] == 'technician'):
                                return u'no'
                            if (data['job'] != 'technician'):
                                return u'yes'
                        if (data['duration'] > 170):
                            return u'yes'
                    if (data['poutcome'] != 'success'):
                        return u'no'
        if (data['month'] == 'nov'):
            if (data.get('day') is None):
                return u'no'
            if (data['day'] <= 16):
                if (data['duration'] <= 140):
                    return u'no'
                if (data['duration'] > 140):
                    if (data.get('poutcome') is None):
                        return u'yes'
                    if (data['poutcome'] == 'success'):
                        return u'yes'
                    if (data['poutcome'] != 'success'):
                        if (data.get('pdays') is None):
                            return u'yes'
                        if (data['pdays'] <= 94):
                            return u'yes'
                        if (data['pdays'] > 94):
                            if (data.get('balance') is None):
                                return u'no'
                            if (data['balance'] <= 1623):
                                return u'no'
                            if (data['balance'] > 1623):
                                return u'yes'
            if (data['day'] > 16):
                if (data['day'] <= 24):
                    if (data['duration'] <= 218):
                        if (data.get('contact') is None):
                            return u'no'
                        if (data['contact'] == 'unknown'):
                            return u'no'
                        if (data['contact'] != 'unknown'):
                            if (data.get('age') is None):
                                return u'no'
                            if (data['age'] <= 74):
                                return u'no'
                            if (data['age'] > 74):
                                return u'yes'
                    if (data['duration'] > 218):
                        if (data.get('age') is None):
                            return u'no'
                        if (data['age'] <= 27):
                            if (data.get('housing') is None):
                                return u'yes'
                            if (data['housing'] == 'yes'):
                                return u'no'
                            if (data['housing'] == 'no'):
                                return u'yes'
                        if (data['age'] > 27):
                            if (data.get('housing') is None):
                                return u'no'
                            if (data['housing'] == 'yes'):
                                return u'no'
                            if (data['housing'] == 'no'):
                                return u'no'
                if (data['day'] > 24):
                    if (data['duration'] <= 156):
                        if (data.get('job') is None):
                            return u'no'
                        if (data['job'] == 'unemployed'):
                            return u'yes'
                        if (data['job'] != 'unemployed'):
                            return u'no'
                    if (data['duration'] > 156):
                        if (data.get('pdays') is None):
                            return u'yes'
                        if (data['pdays'] <= 95):
                            if (data.get('balance') is None):
                                return u'no'
                            if (data['balance'] <= 1025):
                                return u'no'
                            if (data['balance'] > 1025):
                                return u'yes'
                        if (data['pdays'] > 95):
                            return u'yes'
        if (data['month'] == 'jan'):
            if (data.get('day') is None):
                return u'no'
            if (data['day'] <= 27):
                if (data['duration'] <= 138):
                    if (data.get('age') is None):
                        return u'no'
                    if (data['age'] <= 25):
                        return u'yes'
                    if (data['age'] > 25):
                        if (data.get('job') is None):
                            return u'no'
                        if (data['job'] == 'unemployed'):
                            if (data.get('poutcome') is None):
                                return u'yes'
                            if (data['poutcome'] == 'other'):
                                return u'no'
                            if (data['poutcome'] == 'unknown'):
                                return u'yes'
                        if (data['job'] != 'unemployed'):
                            return u'no'
                if (data['duration'] > 138):
                    if (data['duration'] <= 361):
                        if (data.get('pdays') is None):
                            return u'no'
                        if (data['pdays'] <= 231):
                            return u'no'
                        if (data['pdays'] > 231):
                            if (data.get('balance') is None):
                                return u'yes'
                            if (data['balance'] <= 11051):
                                return u'yes'
                            if (data['balance'] > 11051):
                                return u'no'
                    if (data['duration'] > 361):
                        return u'yes'
            if (data['day'] > 27):
                if (data.get('poutcome') is None):
                    return u'no'
                if (data['poutcome'] == 'success'):
                    if (data.get('pdays') is None):
                        return u'no'
                    if (data['pdays'] <= 162):
                        if (data['day'] <= 28):
                            return u'yes'
                        if (data['day'] > 28):
                            if (data.get('loan') is None):
                                return u'no'
                            if (data['loan'] == 'yes'):
                                return u'yes'
                            if (data['loan'] == 'no'):
                                return u'no'
                    if (data['pdays'] > 162):
                        if (data.get('balance') is None):
                            return u'no'
                        if (data['balance'] <= 2086):
                            return u'no'
                        if (data['balance'] > 2086):
                            return u'yes'
                if (data['poutcome'] != 'success'):
                    if (data['duration'] <= 125):
                        return u'no'
                    if (data['duration'] > 125):
                        if (data.get('balance') is None):
                            return u'no'
                        if (data['balance'] <= 1897):
                            if (data.get('housing') is None):
                                return u'no'
                            if (data['housing'] == 'yes'):
                                return u'no'
                            if (data['housing'] == 'no'):
                                return u'no'
                        if (data['balance'] > 1897):
                            return u'no'
        if (data['month'] == 'sep'):
            if (data['duration'] <= 162):
                if (data.get('poutcome') is None):
                    return u'no'
                if (data['poutcome'] == 'success'):
                    if (data['duration'] <= 82):
                        return u'no'
                    if (data['duration'] > 82):
                        if (data.get('day') is None):
                            return u'yes'
                        if (data['day'] <= 10):
                            if (data.get('pdays') is None):
                                return u'no'
                            if (data['pdays'] <= 100):
                                return u'yes'
                            if (data['pdays'] > 100):
                                return u'no'
                        if (data['day'] > 10):
                            return u'yes'
                if (data['poutcome'] != 'success'):
                    return u'no'
            if (data['duration'] > 162):
                if (data.get('poutcome') is None):
                    return u'yes'
                if (data['poutcome'] == 'success'):
                    if (data.get('pdays') is None):
                        return u'yes'
                    if (data['pdays'] <= 66):
                        return u'no'
                    if (data['pdays'] > 66):
                        return u'yes'
                if (data['poutcome'] != 'success'):
                    if (data.get('age') is None):
                        return u'yes'
                    if (data['age'] <= 81):
                        if (data.get('day') is None):
                            return u'yes'
                        if (data['day'] <= 5):
                            return u'no'
                        if (data['day'] > 5):
                            return u'yes'
                    if (data['age'] > 81):
                        return u'no'
        if (data['month'] == 'mar'):
            if (data['duration'] <= 171):
                return u'no'
            if (data['duration'] > 171):
                if (data.get('poutcome') is None):
                    return u'yes'
                if (data['poutcome'] == 'failure'):
                    if (data.get('day') is None):
                        return u'no'
                    if (data['day'] <= 13):
                        if (data.get('contact') is None):
                            return u'yes'
                        if (data['contact'] == 'telephone'):
                            return u'no'
                        if (data['contact'] != 'telephone'):
                            if (data.get('job') is None):
                                return u'yes'
                            if (data['job'] == 'management'):
                                return u'no'
                            if (data['job'] != 'management'):
                                return u'yes'
                    if (data['day'] > 13):
                        if (data.get('balance') is None):
                            return u'no'
                        if (data['balance'] <= 3483):
                            if (data.get('previous') is None):
                                return u'no'
                            if (data['previous'] <= 6):
                                return u'no'
                            if (data['previous'] > 6):
                                return u'yes'
                        if (data['balance'] > 3483):
                            if (data['duration'] <= 301):
                                return u'yes'
                            if (data['duration'] > 301):
                                return u'no'
                if (data['poutcome'] != 'failure'):
                    return u'yes'
    if (data['duration'] > 392):
        if (data['duration'] <= 643):
            if (data.get('poutcome') is None):
                return u'no'
            if (data['poutcome'] == 'success'):
                return u'yes'
            if (data['poutcome'] != 'success'):
                if (data.get('contact') is None):
                    return u'no'
                if (data['contact'] == 'unknown'):
                    if (data['duration'] <= 476):
                        if (data['poutcome'] == 'other'):
                            return u'yes'
                        if (data['poutcome'] != 'other'):
                            if (data.get('month') is None):
                                return u'no'
                            if (data['month'] == 'mar'):
                                return u'yes'
                            if (data['month'] != 'mar'):
                                return u'no'
                    if (data['duration'] > 476):
                        if (data.get('month') is None):
                            return u'no'
                        if (data['month'] == 'may'):
                            return u'no'
                        if (data['month'] == 'apr'):
                            return u'yes'
                        if (data['month'] == 'oct'):
                            return u'no'
                        if (data['month'] == 'nov'):
                            return u'no'
                        if (data['month'] == 'jul'):
                            if (data.get('job') is None):
                                return u'no'
                            if (data['job'] == 'services'):
                                return u'yes'
                            if (data['job'] != 'services'):
                                return u'no'
                        if (data['month'] == 'jun'):
                            return u'no'
                        if (data['month'] == 'aug'):
                            return u'yes'
                if (data['contact'] != 'unknown'):
                    if (data.get('housing') is None):
                        return u'no'
                    if (data['housing'] == 'yes'):
                        if (data['duration'] <= 521):
                            if (data.get('pdays') is None):
                                return u'no'
                            if (data['pdays'] <= 383):
                                return u'no'
                            if (data['pdays'] > 383):
                                return u'yes'
                        if (data['duration'] > 521):
                            if (data.get('month') is None):
                                return u'no'
                            if (data['month'] == 'oct'):
                                return u'yes'
                            if (data['month'] == 'jul'):
                                return u'no'
                            if (data['month'] == 'dec'):
                                return u'yes'
                            if (data['month'] == 'jun'):
                                return u'yes'
                            if (data['month'] == 'apr'):
                                return u'no'
                            if (data['month'] == 'feb'):
                                return u'no'
                            if (data['month'] == 'may'):
                                return u'no'
                            if (data['month'] == 'aug'):
                                return u'no'
                            if (data['month'] == 'nov'):
                                return u'no'
                            if (data['month'] == 'jan'):
                                return u'no'
                            if (data['month'] == 'sep'):
                                return u'yes'
                            if (data['month'] == 'mar'):
                                return u'yes'
                    if (data['housing'] == 'no'):
                        if (data.get('month') is None):
                            return u'no'
                        if (data['month'] == 'apr'):
                            return u'yes'
                        if (data['month'] != 'apr'):
                            if (data.get('loan') is None):
                                return u'no'
                            if (data['loan'] == 'yes'):
                                return u'no'
                            if (data['loan'] == 'no'):
                                return u'no'
        if (data['duration'] > 643):
            if (data['duration'] <= 841):
                if (data.get('contact') is None):
                    return u'no'
                if (data['contact'] == 'unknown'):
                    return u'no'
                if (data['contact'] != 'unknown'):
                    if (data.get('poutcome') is None):
                        return u'no'
                    if (data['poutcome'] == 'success'):
                        return u'yes'
                    if (data['poutcome'] != 'success'):
                        if (data.get('day') is None):
                            return u'no'
                        if (data['day'] <= 15):
                            if (data.get('month') is None):
                                return u'yes'
                            if (data['month'] == 'apr'):
                                return u'no'
                            if (data['month'] != 'apr'):
                                return u'yes'
                        if (data['day'] > 15):
                            if (data.get('housing') is None):
                                return u'no'
                            if (data['housing'] == 'yes'):
                                return u'no'
                            if (data['housing'] == 'no'):
                                return u'yes'
            if (data['duration'] > 841):
                if (data.get('contact') is None):
                    return u'yes'
                if (data['contact'] == 'cellular'):
                    if (data.get('marital') is None):
                        return u'yes'
                    if (data['marital'] == 'married'):
                        if (data.get('poutcome') is None):
                            return u'yes'
                        if (data['poutcome'] == 'success'):
                            return u'yes'
                        if (data['poutcome'] != 'success'):
                            if (data.get('month') is None):
                                return u'yes'
                            if (data['month'] == 'oct'):
                                return u'no'
                            if (data['month'] != 'oct'):
                                return u'yes'
                    if (data['marital'] != 'married'):
                        if (data.get('month') is None):
                            return u'yes'
                        if (data['month'] == 'nov'):
                            if (data.get('poutcome') is None):
                                return u'no'
                            if (data['poutcome'] == 'unknown'):
                                return u'yes'
                            if (data['poutcome'] != 'unknown'):
                                return u'no'
                        if (data['month'] != 'nov'):
                            if (data.get('pdays') is None):
                                return u'yes'
                            if (data['pdays'] <= 233):
                                return u'yes'
                            if (data['pdays'] > 233):
                                return u'yes'
                if (data['contact'] != 'cellular'):
                    if (data.get('balance') is None):
                        return u'yes'
                    if (data['balance'] <= 758):
                        return u'no'
                    if (data['balance'] > 758):
                        return u'yes'
